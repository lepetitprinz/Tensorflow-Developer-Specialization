# %% [markdown]
# ### Explore the Example Data

# %%
import os

# %%
base_dir = os.path.join('/', 'Users', 'yjkim', 'data', 'images', 'cats_and_dogs_filterd')

# %%
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat&dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat&dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
train_cats_fnames = os.listdir(train_cats_dir)
train_dogs_fnames = os.listdir(train_dogs_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-779f20e062e1> in <module>()
# ----> 1 train_cats_fnames = os.listdir(train_cats_dir)
#       2 train_dogs_fnames = os.listdir(train_dogs_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/yjkim/data/images/cats_and_dogs_filterd/train/cats'
